# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Procurement KPI Analysis Dataset.csv")

# %%
df.isnull().sum()
# Out:
# PO_ID                 0
# Supplier              0
# Order_Date            0
# Delivery_Date        87
# Item_Category         0
# Order_Status          0
# Quantity              0
# Unit_Price            0
# Negotiated_Price      0
# Defective_Units     136
# Compliance            0
# dtype: int64

# %%
df.head(10)
# Out:
#       PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 0  PO-00001        Alpha_Inc  2023-10-17    2023-10-25  Office Supplies
# 1  PO-00002  Delta_Logistics  2022-04-25    2022-05-05  Office Supplies
# 2  PO-00003         Gamma_Co  2022-01-26    2022-02-15              MRO
# 3  PO-00004    Beta_Supplies  2022-10-09    2022-10-28        Packaging
# 4  PO-00005  Delta_Logistics  2022-09-08    2022-09-20    Raw Materials
# 5  PO-00006    Epsilon_Group  2022-08-17    2022-08-29              MRO
# 6  PO-00007         Gamma_Co  2022-05-23    2022-06-03              MRO
# 7  PO-00008        Alpha_Inc  2022-04-15    2022-04-29              MRO
# 8  PO-00009         Gamma_Co  2023-11-24    2023-11-28    Raw Materials
# 9  PO-00010         Gamma_Co  2023-07-13    2023-07-25    Raw Materials
#
#           Order_Status  Quantity  Unit_Price  Negotiated_Price  \
# 0            Cancelled      1176       20.13             17.81
# 1            Delivered      1509       39.32             37.34
# 2            Delivered       910       95.51             92.26
# 3            Delivered      1344       99.85             95.52
# 4            Delivered      1180       64.07             60.53
# 5            Delivered      1145       69.21             63.57
# 6            Delivered      1774       51.37             47.82
# 7            Delivered      1094       36.93             32.78
# 8  Partially Delivered      1688       43.93             39.89
# 9              Pending       171       76.87             70.20
#
#    Defective_Units Compliance
# 0              NaN        Yes
# 1            235.0        Yes
# 2             41.0        Yes
# 3            112.0        Yes
# 4            171.0         No
# 5             39.0        Yes
# 6             96.0         No
# 7             22.0        Yes
# 8             89.0        Yes
# 9              8.0        Yes

# %%
df['Supplier'].value_counts()
# Out:
# Supplier
# Delta_Logistics    171
# Epsilon_Group      166
# Beta_Supplies      156
# Gamma_Co           143
# Alpha_Inc          141
# Name: count, dtype: int64

# %%
df['Order_Status'].value_counts()
# Out:
# Order_Status
# Delivered              560
# Pending                 81
# Partially Delivered     73
# Cancelled               63
# Name: count, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(
    df.drop(columns=['Compliance']), 
    df['Compliance'], 
    test_size=0.2, 
    random_state=45  
)

# %%
x_train.head(10)
# Out:
#         PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 227  PO-00228    Epsilon_Group  2022-08-24    2022-08-27        Packaging
# 297  PO-00298        Alpha_Inc  2022-08-07    2022-08-10  Office Supplies
# 69   PO-00070        Alpha_Inc  2022-04-14    2022-04-22              MRO
# 540  PO-00541    Epsilon_Group  2023-02-23    2023-03-08  Office Supplies
# 394  PO-00395         Gamma_Co  2023-11-11    2023-11-18              MRO
# 581  PO-00582  Delta_Logistics  2023-09-27    2023-10-12  Office Supplies
# 542  PO-00543    Epsilon_Group  2023-02-17    2023-02-23      Electronics
# 256  PO-00257    Beta_Supplies  2022-04-10    2022-04-24        Packaging
# 564  PO-00565    Epsilon_Group  2023-09-14    2023-10-03    Raw Materials
# 393  PO-00394        Alpha_Inc  2022-11-03    2022-11-07  Office Supplies
#
#             Order_Status  Quantity  Unit_Price  Negotiated_Price  \
# 227            Delivered      1871       59.96             58.54
# 297            Delivered       296       40.38             35.25
# 69             Delivered       291       98.70             87.02
# 540            Delivered      1738       67.91             61.15
# 394            Delivered      1969       71.71             61.96
# 581  Partially Delivered      1179       90.14             82.63
# 542            Delivered       624       74.39             66.30
# 256            Delivered      1900       24.11             23.45
# 564              Pending        54       32.28             28.65
# 393            Delivered       963       64.96             64.07
#
#      Defective_Units
# 227             47.0
# 297              NaN
# 69               9.0
# 540              NaN
# 394              NaN
# 581            194.0
# 542             18.0
# 256            188.0
# 564              3.0
# 393             20.0

# %%
transformer = ColumnTransformer(
    transformers=[
        ('ordinal', OrdinalEncoder(categories=[['Cancelled', 'Pending', 'Partially Delivered', 'Delivered']]), ['Order_Status']),
        ('onehot', OneHotEncoder(sparse_output=False, drop='first'), ['Supplier'])
    ],
    remainder='passthrough'
)

# %%
x_train_new = transformer.fit_transform(x_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 x_train_new = transformer.fit_transform(x_train).pd.DataFrame
#
# AttributeError: 'numpy.ndarray' object has no attribute 'pd'

# %%
x_test_new
# Out:
# array([[3.0, 0.0, 0.0, ..., 86.91, 78.44, 18.0],
#        [3.0, 0.0, 0.0, ..., 69.73, 63.8, 41.0],
#        [3.0, 0.0, 0.0, ..., 16.46, 14.2, 57.0],
#        ...,
#        [3.0, 0.0, 0.0, ..., 11.92, 11.72, 76.0],
#        [3.0, 0.0, 0.0, ..., 72.23, 67.86, 53.0],
#        [3.0, 0.0, 0.0, ..., 34.2, 30.5, 25.0]], dtype=object)

# %%
x_train_new = pd.DataFrame(x_test_new)

# %%
x_train_new.head(10)
# Out:
#     0    1    2    3    4         5           6           7                8   \
# 0  3.0  0.0  0.0  1.0  0.0  PO-00515  2023-01-30  2023-02-16        Packaging
# 1  3.0  0.0  0.0  1.0  0.0  PO-00244  2023-11-17  2023-11-29      Electronics
# 2  3.0  0.0  0.0  1.0  0.0  PO-00314  2022-07-14  2022-08-03    Raw Materials
# 3  3.0  0.0  0.0  0.0  0.0  PO-00420  2022-02-15  2022-03-04    Raw Materials
# 4  3.0  0.0  0.0  0.0  1.0  PO-00031  2022-10-12  2022-10-26      Electronics
# 5  3.0  0.0  0.0  1.0  0.0  PO-00299  2023-02-15  2023-02-27              MRO
# 6  3.0  0.0  0.0  0.0  1.0  PO-00686  2023-02-04         NaN      Electronics
# 7  3.0  0.0  1.0  0.0  0.0  PO-00327  2023-06-28  2023-07-01  Office Supplies
# 8  3.0  0.0  0.0  1.0  0.0  PO-00453  2023-11-14  2023-12-01  Office Supplies
# 9  3.0  0.0  0.0  1.0  0.0  PO-00651  2022-10-20         NaN              MRO
#
#      9      10     11     12
# 0   970  86.91  78.44   18.0
# 1  1332  69.73   63.8   41.0
# 2  1584  16.46   14.2   57.0
# 3   509  76.76  74.72    7.0
# 4   326   18.1  15.92    NaN
# 5   885  88.28   80.8   31.0
# 6  1618  32.76  28.41   62.0
# 7  1004  96.51   92.9  146.0
# 8  1585  56.38  53.05    NaN
# 9  1807  69.47   60.0   50.0
